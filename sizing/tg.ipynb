# %%
import numpy as np
import scipy.constants as sc
import matplotlib.pyplot as plt
from pygmid import Lookup as lk

# %%
choice = 1
devices = ['nfet_01v8_lvt', 'nfet_01v8', 'pfet_01v8_lvt', 'pfet_01v8']
fet = lk('../../lookuptable/skywater130a/'+devices[choice]+'.mat')

# %%
# plot gm/gds versus gm/ID for all L
l = 0.15
VDS1 = 1.8
VGS1 = 1.8
VSB1 = 0
ID = 523e-6
for w in range(1,10):
    Rds = 1 / fet.lookup('GDS', ID_W= ID/w, L=l, VGS=VGS1 VDS=VDS1, VSB=VSB1)
    print(Rds)
